# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
    save = pickle.load(f)
    train_dataset = save['train_dataset']
    train_labels = save['train_labels']
    valid_dataset = save['valid_dataset']
    valid_labels = save['valid_labels']
    test_dataset = save['test_dataset']
    test_labels = save['test_labels']
    del save  # hint to help gc free up memory
    print('Training set', train_dataset.shape, train_labels.shape)
    print('Validation set', valid_dataset.shape, valid_labels.shape)
    print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
    dataset = dataset.reshape(
        (-1, image_size, image_size, num_channels)).astype(np.float32)
    labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
    return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
    return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer3_weights = tf.Variable(tf.truncated_normal(
        [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal(
        [num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer1_biases)
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_biases)
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases
  
    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels))
    
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
                valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.014513
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Initialized
# Minibatch loss at step 0: 3.014513
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.827273
# Minibatch accuracy: 31.2%
# Validation accuracy: 48.3%
# Minibatch loss at step 100: 1.166525
# Minibatch accuracy: 50.0%
# Validation accuracy: 66.7%
# Minibatch loss at step 50: 1.827273
# Minibatch accuracy: 31.2%
# Validation accuracy: 48.3%
# Minibatch loss at step 100: 1.166525
# Minibatch accuracy: 50.0%
# Validation accuracy: 66.7%
# Minibatch loss at step 150: 0.458675
# Minibatch accuracy: 87.5%
# Validation accuracy: 73.7%
# Minibatch loss at step 150: 0.458675
# Minibatch accuracy: 87.5%
# Validation accuracy: 73.7%
# Minibatch loss at step 200: 0.889890
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.9%
# Minibatch loss at step 250: 1.398918
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.8%
# Minibatch loss at step 200: 0.889890
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.9%
# Minibatch loss at step 250: 1.398918
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.8%
# Minibatch loss at step 300: 0.381729
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.2%
# Minibatch loss at step 350: 0.381032
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.0%
# Minibatch loss at step 300: 0.381729
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.2%
# Minibatch loss at step 350: 0.381032
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.0%
# Minibatch loss at step 400: 0.318606
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.3%
# Minibatch loss at step 400: 0.318606
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.3%
# Minibatch loss at step 450: 0.954231
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.8%
# Minibatch loss at step 500: 0.826573
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 450: 0.954231
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.8%
# Minibatch loss at step 500: 0.826573
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 550: 0.874300
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.9%
# Minibatch loss at step 600: 0.347726
# Minibatch accuracy: 87.5%
# Minibatch loss at step 550: 0.874300
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.9%
# Minibatch loss at step 600: 0.347726
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.3%
# Minibatch loss at step 650: 1.104975
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.0%
# Validation accuracy: 81.3%
# Minibatch loss at step 650: 1.104975
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.0%
# Minibatch loss at step 700: 0.678386
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 750: 0.125034
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.8%
# Minibatch loss at step 700: 0.678386
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 750: 0.125034
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.8%
# Minibatch loss at step 800: 0.710950
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# Minibatch loss at step 850: 0.983115
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.6%
# Minibatch loss at step 800: 0.710950
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# Minibatch loss at step 850: 0.983115
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.6%
# Minibatch loss at step 900: 0.723919
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 950: 0.618101
# Minibatch accuracy: 81.2%
# Minibatch loss at step 900: 0.723919
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 950: 0.618101
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.1%
# Minibatch loss at step 1000: 0.367009
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Validation accuracy: 83.1%
# Minibatch loss at step 1000: 0.367009
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Test accuracy: 88.9%
# Test accuracy: 88.9%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer3_weights = tf.Variable(tf.truncated_normal(
        [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal(
        [num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        max_pooling = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(max_pooling + layer1_biases)
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
        max_pooling = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(max_pooling + layer2_biases)
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases
  
    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels))
    
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
                valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.400790
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.188261
# Minibatch accuracy: 12.5%
# Validation accuracy: 27.9%
# Minibatch loss at step 100: 1.238825
# Minibatch accuracy: 50.0%
# Validation accuracy: 58.7%
# Minibatch loss at step 150: 0.469989
# Minibatch accuracy: 87.5%
# Validation accuracy: 72.9%
# Minibatch loss at step 200: 0.927892
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.3%
# Minibatch loss at step 250: 1.189962
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.6%
# Minibatch loss at step 300: 0.427258
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.9%
# Minibatch loss at step 350: 0.399091
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.1%
# Minibatch loss at step 400: 0.340701
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.7%
# Minibatch loss at step 450: 0.794820
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.4%
# Minibatch loss at step 500: 0.626511
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.1%
# Minibatch loss at step 550: 0.854540
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.9%
# Minibatch loss at step 600: 0.390046
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 650: 0.758773
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 700: 0.639507
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.9%
# Minibatch loss at step 750: 0.068127
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.5%
# Minibatch loss at step 800: 0.692131
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.3%
# Minibatch loss at step 850: 0.818404
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.3%
# Minibatch loss at step 900: 0.571275
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.7%
# Minibatch loss at step 950: 0.476154
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.8%
# Minibatch loss at step 1000: 0.329917
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.8%
# Test accuracy: 90.7%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    size3 = ((image_size - patch_size + 1) // 2 - patch_size + 1) // 2
    layer3_weights = tf.Variable(tf.truncated_normal(
      [size3 * size3 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
    # Model.
    def model(data):
        # C1 input 28 x 28
        conv1 = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='VALID')
        bias1 = tf.nn.relu(conv1 + layer1_biases)
        # S2 input 24 x 24
        pool2 = tf.nn.avg_pool(bias1, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
        # C3 input 12 x 12
        conv3 = tf.nn.conv2d(pool2, layer2_weights, [1, 1, 1, 1], padding='VALID')
        bias3 = tf.nn.relu(conv3 + layer2_biases)
        dropout = tf.nn.dropout(bias3, keep_prob=0.6)
        # S4 input 8 x 8
        pool4 = tf.nn.avg_pool(dropout, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
        # F6 input 4 x 4
        shape = pool4.get_shape().as_list()
        reshape = tf.reshape(pool4, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases
  
    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels))
    
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 10001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 100 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
                valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.839521
# Minibatch accuracy: 12.5%
# Validation accuracy: 9.9%
# Minibatch loss at step 100: 1.216687
# Minibatch accuracy: 43.8%
# Validation accuracy: 62.3%
# Minibatch loss at step 200: 0.951558
# Minibatch accuracy: 75.0%
# Validation accuracy: 70.9%
# Minibatch loss at step 300: 0.619481
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.5%
# Minibatch loss at step 400: 0.385647
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.9%
# Minibatch loss at step 500: 0.750005
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.8%
# Minibatch loss at step 600: 0.349633
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.5%
# Minibatch loss at step 700: 0.879044
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.7%
# Minibatch loss at step 800: 0.621916
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.8%
# Minibatch loss at step 900: 0.767089
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.8%
# Minibatch loss at step 1000: 0.426131
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.9%
# Minibatch loss at step 1100: 0.763895
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.8%
# Minibatch loss at step 1200: 1.025758
# Minibatch accuracy: 62.5%
# Validation accuracy: 81.3%
# Minibatch loss at step 1300: 0.381568
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.9%
# Minibatch loss at step 1400: 0.400327
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.2%
# Minibatch loss at step 1500: 0.679658
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.6%
# Minibatch loss at step 1600: 1.149744
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 1700: 0.748447
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 1800: 0.496262
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 1900: 0.283178
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.8%
# Minibatch loss at step 2000: 0.168068
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.0%
# Minibatch loss at step 2100: 0.303744
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.3%
# Minibatch loss at step 2200: 0.562131
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.8%
# Minibatch loss at step 2300: 0.728506
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.7%
# Minibatch loss at step 2400: 0.481861
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.3%
# Minibatch loss at step 2500: 0.681029
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.3%
# Minibatch loss at step 2600: 0.336199
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.7%
# Minibatch loss at step 2700: 0.410598
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.5%
# Minibatch loss at step 2800: 0.531391
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.9%
# Minibatch loss at step 2900: 0.541942
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.0%
# Minibatch loss at step 3000: 0.625432
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.2%
# Minibatch loss at step 3100: 0.462009
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.4%
# Minibatch loss at step 3200: 0.473773
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 3300: 0.107881
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.7%
# Minibatch loss at step 3400: 0.601595
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.4%
# Minibatch loss at step 3500: 0.301703
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.8%
# Minibatch loss at step 3600: 0.241154
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.5%
# Minibatch loss at step 3700: 1.176522
# Minibatch accuracy: 62.5%
# Validation accuracy: 84.6%
# Minibatch loss at step 3800: 0.014022
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.5%
# Minibatch loss at step 3900: 0.598163
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.5%
# Minibatch loss at step 4000: 0.497240
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 4100: 0.421222
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.1%
# Minibatch loss at step 4200: 0.326148
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.8%
# Minibatch loss at step 4300: 0.845373
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.2%
# Minibatch loss at step 4400: 1.331721
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.3%
# Minibatch loss at step 4500: 0.673101
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.4%
# Minibatch loss at step 4600: 0.354792
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 4700: 0.474097
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 4800: 0.382833
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.5%
# Minibatch loss at step 4900: 0.221189
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.8%
# Minibatch loss at step 5000: 1.332019
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 5100: 0.299357
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.8%
# Minibatch loss at step 5200: 0.417401
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.9%
# Minibatch loss at step 5300: 0.224420
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 5400: 0.461558
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.7%
# Minibatch loss at step 5500: 0.463095
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.6%
# Minibatch loss at step 5600: 0.245958
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 5700: 0.509801
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 5800: 0.322452
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.6%
# Minibatch loss at step 5900: 0.902889
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.5%
# Minibatch loss at step 6000: 0.124409
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.8%
# Minibatch loss at step 6100: 0.874241
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 6200: 1.116165
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 6300: 0.823290
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.6%
# Minibatch loss at step 6400: 0.152093
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.8%
# Minibatch loss at step 6500: 0.837321
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 6600: 0.452275
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.0%
# Minibatch loss at step 6700: 0.237077
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 6800: 0.706895
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 6900: 0.463392
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.2%
# Minibatch loss at step 7000: 0.780524
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.0%
# Minibatch loss at step 7100: 0.412222
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 7200: 0.631423
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.2%
# Minibatch loss at step 7300: 0.542481
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 7400: 0.029442
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.6%
# Minibatch loss at step 7500: 0.238067
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.0%
# Minibatch loss at step 7600: 0.587898
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 7700: 0.261802
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 7800: 0.322695
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 7900: 0.054333
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.1%
# Minibatch loss at step 8000: 0.432216
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 8100: 0.351122
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 8200: 0.227401
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 8300: 0.241590
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.7%
# Minibatch loss at step 8400: 0.346338
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 8500: 0.387564
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 8600: 0.375666
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 8700: 0.269619
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 8800: 0.271787
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 8900: 0.591107
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.4%
# Minibatch loss at step 9000: 0.391469
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 9100: 0.355918
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 9200: 0.198479
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 9300: 1.100272
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.3%
# Minibatch loss at step 9400: 0.313631
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 9500: 0.208278
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 9600: 0.323178
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 9700: 0.153711
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 9800: 0.421604
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.6%
# Minibatch loss at step 9900: 0.670496
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.3%
# Minibatch loss at step 10000: 0.123253
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Test accuracy: 93.1%
