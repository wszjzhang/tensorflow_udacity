# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
          'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5240, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'originated', 'anarchism', 'of', 'term', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
#with graph.as_default():
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, 
                               train_labels, embed, num_sampled, vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
import time

num_steps = 100001
t = time.time()
with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
    
print(time.time()-t)
# Out:
# Initialized
# Average loss at step 0: 7.366865
# Nearest to no: fermilab, bucky, father, nonexistent, lc, mike, surveyor, basayev,
# Nearest to and: minogue, halfwidth, devil, barak, alef, psychiatrists, gorgon, jmp,
# Nearest to who: silicates, terrace, decrypted, dosage, sombre, unsafe, nuh, equated,
# Nearest to most: kusanagi, wicca, grattan, homeostasis, bullshit, overrun, vestry, better,
# Nearest to only: grouse, fragrance, unmolested, teleology, tunable, culmination, athletics, spree,
# Nearest to more: ripening, edgard, scenario, incrementally, sarcasm, celebrations, predicting, harriers,
# Nearest to however: jurists, elam, award, startup, darkness, argent, disallowed, airfield,
# Nearest to between: gendered, keyboardist, moyen, lawmakers, seclusion, reelection, lakeside, hectares,
# Nearest to over: cocker, magic, apparel, obedient, winch, msi, circumstances, lemurs,
# Nearest to called: jujutsu, motorbikes, caspian, lambeau, millennium, mathew, penetrative, sucrose,
# Nearest to world: gholas, formulas, prosecutor, mico, group, shamanistic, levitt, orson,
# Nearest to their: corbett, sdp, botham, centre, appletalk, summits, rockingham, stables,
# Nearest to history: mets, imitative, bootstrapping, brun, swerve, voltaire, wedded, intervarsity,
# Nearest to on: backus, anoa, equivalently, saxon, compilation, award, caesaris, archetypal,
# Nearest to used: cubism, gomorrah, power, gurps, accusations, xun, inhale, freebase,
# Nearest to states: blanking, unreal, dannebrog, bremen, add, thrives, locarno, songwriters,
# Average loss at step 2000: 4.350023
# Average loss at step 4000: 3.852697
# Average loss at step 6000: 3.755368
# Average loss at step 8000: 3.612474
# Average loss at step 10000: 3.681007
# Nearest to no: lc, notably, mike, a, tabloids, hartman, styled, footnote,
# Nearest to and: or, kurukshetra, for, s, trioxide, from, ones, birthday,
# Nearest to who: unsafe, he, mesa, never, fetching, terrace, nsc, memoriam,
# Nearest to most: some, phospholipid, better, wicca, grattan, kyrgyz, kusanagi, firewire,
# Nearest to only: grouse, delocalised, fragrance, parallel, spree, nor, drunk, kohl,
# Nearest to more: predicting, ripening, dualities, certifications, algirdas, defaults, sarcasm, incrementally,
# Nearest to however: but, has, sensibilities, disallowed, monistic, although, indonesian, fictional,
# Nearest to between: phages, gendered, payne, bova, heal, supp, lawmakers, for,
# Nearest to over: cocker, where, situ, devoting, hearing, aikido, erinyes, monegasque,
# Nearest to called: scullin, area, millennium, lambeau, philanthropy, jujutsu, martov, cystic,
# Nearest to world: gholas, group, uncredited, persuasion, cheerleading, alamo, formulas, levitt,
# Nearest to their: the, his, its, reza, yokoi, annan, her, zork,
# Nearest to history: bootstrapping, mets, dpp, gain, rap, intensely, kops, voltaire,
# Nearest to on: in, into, giacomo, at, caesaris, upon, between, samsara,
# Nearest to used: referred, gomorrah, power, establishments, caeiro, gurps, freefall, tetragrammaton,
# Nearest to states: blanking, consumption, mandela, thrives, andrey, edition, bremen, points,
# Average loss at step 12000: 3.542289
# Average loss at step 14000: 3.535626
# Average loss at step 16000: 3.476003
# Average loss at step 18000: 3.562938
# Average loss at step 20000: 3.587439
# Nearest to no: there, it, styled, protagonists, ammonia, configurable, tabloids, depart,
# Nearest to and: or, but, who, ramp, coimbra, of, sluggish, anytime,
# Nearest to who: he, they, which, and, also, unsafe, nsc, killings,
# Nearest to most: more, phospholipid, some, many, overriding, loony, grattan, age,
# Nearest to only: grouse, existent, drunk, not, proselytizing, spree, pharos, perfectly,
# Nearest to more: most, less, predicting, dualities, certifications, very, ripening, defaults,
# Nearest to however: but, although, ndnis, monistic, that, sensibilities, which, labs,
# Nearest to between: with, for, phages, around, payne, from, loudspeaker, supp,
# Nearest to over: situ, cocker, erinyes, lemurs, arcology, where, vara, gong,
# Nearest to called: millennium, cystic, jujutsu, used, scullin, lambeau, characterises, frequently,
# Nearest to world: gholas, holy, persuasion, alamo, assault, mammalia, reporters, inventing,
# Nearest to their: his, its, the, her, yokoi, spectroscopic, these, shalt,
# Nearest to history: bootstrapping, mets, dpp, landmark, rap, gain, kops, pelias,
# Nearest to on: in, during, at, upon, pirated, caesaris, into, newsweek,
# Nearest to used: referred, gomorrah, gurps, caeiro, called, published, considered, verify,
# Nearest to states: blanking, mandela, edition, sig, andrey, thrives, others, songwriters,
# Average loss at step 22000: 3.506810
# Average loss at step 24000: 3.514083
# Average loss at step 26000: 3.341819
# Average loss at step 28000: 3.506113
# Average loss at step 30000: 3.498947
# Nearest to no: tabloids, ammonia, there, clear, distracted, elbows, protagonists, configurable,
# Nearest to and: but, or, herding, which, sluggish, like, ima, in,
# Nearest to who: he, which, they, nsc, never, and, killings, hyperinflation,
# Nearest to most: more, some, many, phospholipid, belief, less, grattan, overriding,
# Nearest to only: drunk, existent, grouse, still, loyola, actually, proselytizing, perfectly,
# Nearest to more: less, most, very, algirdas, dualities, certifications, chairperson, predicting,
# Nearest to however: but, although, that, labs, ndnis, which, monistic, since,
# Nearest to between: with, around, against, payne, into, kingdoms, in, supp,
# Nearest to over: situ, cocker, exploit, aikido, renounces, lemurs, devoting, deriving,
# Nearest to called: cystic, used, moss, millennium, owes, bullpen, becomes, nina,
# Nearest to world: thessaloniki, gibraltar, holy, reporters, persuasion, gholas, assault, hands,
# Nearest to their: its, his, her, the, some, yokoi, our, these,
# Nearest to history: bootstrapping, mets, dpp, amount, landmark, geography, dresser, duddy,
# Nearest to on: upon, during, at, in, from, giacomo, appropriateness, tis,
# Nearest to used: referred, antoninianus, applied, called, considered, elected, played, gurps,
# Nearest to states: blanking, simultaneously, us, others, mandela, songwriters, thrives, unikom,
# Average loss at step 32000: 3.519490
# Average loss at step 34000: 3.492655
# Average loss at step 36000: 3.493676
# Average loss at step 38000: 3.427503
# Average loss at step 40000: 3.350193
# Nearest to no: any, clear, distracted, ammonia, satem, generally, already, also,
# Nearest to and: or, like, but, including, who, kalevala, shirley, stiller,
# Nearest to who: he, which, and, they, never, she, nsc, incremental,
# Nearest to most: more, many, some, both, less, rale, birthday, mueller,
# Nearest to only: drunk, actually, not, usually, grouse, still, existent, tunable,
# Nearest to more: less, most, very, dualities, rather, highly, chairperson, proton,
# Nearest to however: but, although, that, since, where, though, which, brigades,
# Nearest to between: with, around, against, among, through, into, in, heal,
# Nearest to over: situ, exploit, renounces, cocker, occasional, about, stadtholder, devoting,
# Nearest to called: used, moss, becomes, owes, cystic, bullpen, belgian, known,
# Nearest to world: holy, reporters, persuasion, frei, gholas, gibraltar, arsenal, usa,
# Nearest to their: its, his, her, the, yokoi, our, your, these,
# Nearest to history: geography, dpp, bootstrapping, dresser, lesser, adp, envoys, because,
# Nearest to on: upon, during, in, at, against, fulda, locks, into,
# Nearest to used: referred, known, considered, called, released, required, regarded, found,
# Nearest to states: countries, simultaneously, nations, blanking, countrymen, us, others, songwriters,
# Average loss at step 42000: 3.437911
# Average loss at step 44000: 3.437048
# Average loss at step 46000: 3.415361
# Average loss at step 48000: 3.389429
# Average loss at step 50000: 3.437550
# Nearest to no: another, any, little, a, pyrenees, ammonia, configurable, clear,
# Nearest to and: or, but, while, including, anytime, supp, although, who,
# Nearest to who: he, they, which, never, also, but, she, often,
# Nearest to most: more, many, some, all, less, especially, age, both,
# Nearest to only: drunk, grouse, still, not, comparably, given, since, actually,
# Nearest to more: less, most, very, dualities, highly, plenty, rather, predicting,
# Nearest to however: but, although, though, that, where, while, dietary, which,
# Nearest to between: with, around, among, against, hogeschool, payne, vaughan, liouville,
# Nearest to over: exploit, situ, into, stadtholder, fastest, about, out, diligently,
# Nearest to called: used, bullpen, cystic, known, becomes, considered, supercomputers, owes,
# Nearest to world: gibraltar, persuasion, tank, thessaloniki, usa, frei, reporters, inventing,
# Nearest to their: its, his, her, the, our, yokoi, these, your,
# Nearest to history: geography, lesser, dpp, ivanhoe, bootstrapping, freudian, guitars, bjarne,
# Nearest to on: upon, through, at, in, obligate, fulda, appropriateness, against,
# Nearest to used: referred, known, considered, called, required, occurs, regarded, affected,
# Nearest to states: countries, nations, kingdom, simultaneously, countrymen, blanking, us, songwriters,
# Average loss at step 52000: 3.393914
# Average loss at step 54000: 3.449487
# Average loss at step 56000: 3.421704
# Average loss at step 58000: 3.295771
# Average loss at step 60000: 3.382342
# Nearest to no: any, little, there, another, ammonia, only, clear, configurable,
# Nearest to and: or, while, but, including, like, of, frustrations, who,
# Nearest to who: they, never, he, which, she, also, and, still,
# Nearest to most: many, more, some, especially, birthday, draugr, all, less,
# Nearest to only: drunk, still, not, usually, actually, lolita, either, since,
# Nearest to more: less, most, dualities, highly, very, better, unquestioned, rather,
# Nearest to however: but, although, though, that, while, when, cases, there,
# Nearest to between: with, among, around, against, djs, hogeschool, loudspeaker, supp,
# Nearest to over: into, situ, about, equatorial, fastest, exploit, stadtholder, diligently,
# Nearest to called: used, bullpen, supercomputers, known, cystic, becomes, considered, safely,
# Nearest to world: reporters, usa, persuasion, gibraltar, thessaloniki, un, frei, city,
# Nearest to their: its, her, his, our, your, yokoi, my, the,
# Nearest to history: list, geography, meagre, ivanhoe, independant, lesser, timeline, freudian,
# Nearest to on: upon, through, in, vulture, at, tis, obligate, offal,
# Nearest to used: referred, known, called, found, considered, required, occurs, spoken,
# Nearest to states: nations, countries, kingdom, simultaneously, countrymen, feathered, others, us,
# Average loss at step 62000: 3.414610
# Average loss at step 64000: 3.295525
# Average loss at step 66000: 3.369200
# Average loss at step 68000: 3.370241
# Average loss at step 70000: 3.355256
# Nearest to no: little, any, ammonia, another, satem, configurable, distracted, sided,
# Nearest to and: or, but, including, of, while, who, in, lusitanian,
# Nearest to who: which, he, she, never, also, they, often, now,
# Nearest to most: more, many, especially, some, draugr, all, less, both,
# Nearest to only: drunk, since, until, still, actually, ennis, all, last,
# Nearest to more: less, dualities, most, very, highly, scenario, unquestioned, better,
# Nearest to however: but, although, though, while, that, during, since, where,
# Nearest to between: with, among, around, against, hogeschool, executes, loudspeaker, payne,
# Nearest to over: about, stadtholder, situ, equatorial, fastest, viscount, bacilli, diligently,
# Nearest to called: bullpen, used, supercomputers, known, becomes, moss, safely, termed,
# Nearest to world: persuasion, gibraltar, physicists, frei, un, arsenal, dialects, mammalia,
# Nearest to their: his, its, her, the, our, my, your, these,
# Nearest to history: list, geography, independant, freudian, ivanhoe, lesser, posthumous, cognitive,
# Nearest to on: upon, in, through, about, vulture, magazine, giacomo, fulda,
# Nearest to used: referred, known, considered, required, spoken, found, affected, occurs,
# Nearest to states: nations, countries, kingdom, simultaneously, us, state, marr, songwriters,
# Average loss at step 72000: 3.020869
# Average loss at step 74000: 2.897664
# Average loss at step 76000: 3.106566
# Average loss at step 78000: 3.180661
# Average loss at step 80000: 3.288242
# Nearest to no: little, any, distracted, ammonia, another, configurable, satem, it,
# Nearest to and: but, or, however, while, including, supp, with, intercommunal,
# Nearest to who: often, which, also, never, he, they, she, now,
# Nearest to most: more, less, highly, draugr, many, birthday, some, especially,
# Nearest to only: last, first, actually, not, drunk, until, ericaceae, usually,
# Nearest to more: less, most, very, dualities, rather, highly, longer, scenario,
# Nearest to however: but, although, though, while, when, that, and, during,
# Nearest to between: with, among, around, against, in, hogeschool, loudspeaker, within,
# Nearest to over: situ, into, stadtholder, diligently, viscount, yoruba, fastest, exploit,
# Nearest to called: used, named, supercomputers, considered, said, referred, known, safely,
# Nearest to world: gibraltar, persuasion, loco, dialects, amorites, holy, stats, icrc,
# Nearest to their: its, his, her, our, your, my, the, these,
# Nearest to history: list, geography, jerusalem, ivanhoe, politics, independant, freudian, meagre,
# Nearest to on: upon, in, through, obligate, at, fulda, portal, around,
# Nearest to used: referred, known, considered, required, called, spoken, published, occurs,
# Nearest to states: kingdom, nations, countries, us, state, simultaneously, haudenosaunee, environmentalism,
# Average loss at step 82000: 3.287104
# Average loss at step 84000: 3.323374
# Average loss at step 86000: 3.239741
# Average loss at step 88000: 3.361735
# Average loss at step 90000: 3.400331
# Nearest to no: little, any, ammonia, satem, distracted, cameroons, capacities, consensual,
# Nearest to and: or, but, including, jammed, in, while, upload, which,
# Nearest to who: which, often, never, gino, incremental, still, she, they,
# Nearest to most: more, some, less, many, especially, draugr, both, several,
# Nearest to only: actually, always, usually, still, drunk, last, pokes, omphalos,
# Nearest to more: less, most, very, dualities, highly, rather, larger, faster,
# Nearest to however: although, but, though, while, that, during, when, where,
# Nearest to between: with, around, among, in, within, exciting, chimneys, kingdoms,
# Nearest to over: followings, exploit, into, diligently, situ, yoruba, about, charges,
# Nearest to called: referred, named, used, supercomputers, said, considered, bullpen, safely,
# Nearest to world: persuasion, loco, physicists, holy, stagnation, largest, amorites, slurred,
# Nearest to their: its, her, his, the, our, yokoi, your, whose,
# Nearest to history: ivanhoe, list, geography, jerusalem, politics, hacked, tradition, independant,
# Nearest to on: upon, in, through, at, into, lowell, along, appropriateness,
# Nearest to used: referred, known, considered, spoken, found, required, written, regarded,
# Nearest to states: nations, kingdom, countries, us, state, simultaneously, songwriters, antiquities,
# Average loss at step 92000: 3.333184
# Average loss at step 94000: 3.373210
# Average loss at step 96000: 3.091191
# Average loss at step 98000: 3.315798
# Average loss at step 100000: 3.347226
# Nearest to no: any, little, satem, distracted, ammonia, configurable, cameroons, topeka,
# Nearest to and: or, but, including, kournikova, in, manometer, balder, milliardo,
# Nearest to who: never, which, they, he, she, also, gino, often,
# Nearest to most: more, less, many, especially, some, both, all, stray,
# Nearest to only: first, actually, pokes, until, last, always, proselytizing, drunk,
# Nearest to more: less, most, longer, very, rather, highly, larger, dualities,
# Nearest to however: although, but, though, while, that, since, dietary, when,
# Nearest to between: with, around, within, among, kingdoms, in, payne, through,
# Nearest to over: exploit, diligently, situ, followings, through, out, beyond, ignaz,
# Nearest to called: named, referred, used, supercomputers, said, bullpen, considered, known,
# Nearest to world: stagnation, european, persuasion, holy, inquirer, largest, overturning, hands,
# Nearest to their: its, his, her, our, your, whose, my, spectroscopic,
# Nearest to history: list, ivanhoe, geography, jerusalem, politics, meagre, hacked, dobbs,
# Nearest to on: upon, in, during, through, within, at, unclaimed, hawks,
# Nearest to used: referred, known, considered, spoken, regarded, required, found, described,
# Nearest to states: nations, kingdom, countries, us, desolate, state, findings, antiquities,
# 279.5554533004761

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
